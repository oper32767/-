# %% [markdown]
# <a href="https://colab.research.google.com/github/oper32767/-/blob/main/TriCube_AutoInit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ─────────────────────────────────────
# TriCube Auto Initialization Script v1.0
# ─────────────────────────────────────
# 作者：雲龍 × GPT-5 齋藤
# 功能：自動建立三式超立方體五術環境於 Google Drive
# ─────────────────────────────────────

import os, json, hashlib, datetime

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 設定主目錄
ROOT_DIR = "/content/drive/MyDrive/TriCube"
SUB_DIRS = ["data", "five_arts", "schema"]

# 建立目錄結構
for folder in SUB_DIRS:
    path = os.path.join(ROOT_DIR, folder)
    os.makedirs(path, exist_ok=True)
print("✅ TriCube 資料夾結構建立完成：", SUB_DIRS)

# 生成五術結構樣板
five_arts = ["qimen", "liuren", "taiyi", "ziwei", "bazi"]
for art in five_arts:
    filename = f"{ROOT_DIR}/five_arts/tri_cube_hard_{art}.py"
    with open(filename, "w", encoding="utf-8") as f:
        f.write(f"# Placeholder for {art} module\n# Created by TriCube_AutoInit")
print("✅ 五術模組初始化完成。")

# 生成 schema 檔案
schema_files = {
    "five_arts_schema.json": {"schema_version": "1.0", "created": str(datetime.datetime.now())},
    "constitution_hash.json": {"system_hash": hashlib.sha256(b'TriCube_Core_v1').hexdigest()},
    "test_report_schema.json": {"status": "initialized"}
}
for name, data in schema_files.items():
    with open(f"{ROOT_DIR}/schema/{name}", "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4, ensure_ascii=False)
print("✅ Schema 檔案生成完成。")

# 生成系統日誌與 hash
log_path = f"{ROOT_DIR}/system_log.txt"
with open(log_path, "a", encoding="utf-8") as f:
    f.write(f"[{datetime.datetime.now()}] TriCube 系統初始化完成。\n")

hash_path = f"{ROOT_DIR}/hash_commit.txt"
system_hash = hashlib.sha256(str(datetime.datetime.now()).encode()).hexdigest()
with open(hash_path, "w", encoding="utf-8") as f:
    f.write(system_hash)
print("✅ 系統日誌與 hash_commit 寫入完成。")

print("\n🎯 TriCube 第一階段實體化完畢。")
print("所有檔案已自動上傳至 Google Drive/MyDrive/TriCube。")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ TriCube 資料夾結構建立完成： ['data', 'five_arts', 'schema']
# ✅ 五術模組初始化完成。
# ✅ Schema 檔案生成完成。
# ✅ 系統日誌與 hash_commit 寫入完成。
#
# 🎯 TriCube 第一階段實體化完畢。
# 所有檔案已自動上傳至 Google Drive/MyDrive/TriCube。
